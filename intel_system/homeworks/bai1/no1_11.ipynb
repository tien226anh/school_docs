# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
data = pd.read_csv('data/salary.csv')
data
len(data)
X, y = make_classification(n_samples=len(data))

rgb = np.array(['r','g','b'])
plt.scatter(X[:,0],X[:,1],color=rgb[y])
